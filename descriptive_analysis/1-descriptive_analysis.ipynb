# %%
import pandas as pd

# %%
#GORSELLESTIRME_Matplot ve Wordcloud
# !pip install wordcloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
#COUNTVECTOR_OF_BASICLEXICONWORDS_INALLDATASET_32000_FRACTONTWEETS

# %%
#countvector_of_sentiment_lexicon_words_in_all_dataset_32000_fractiontweets

# %%
cv_sentimentlexiconwords_inalldataset={"10 puan":3,"number one":1,"10/10":24,"6/10":1,"8/10":1,"acar":4,"acele":121,"acil":80,"adalet":4,"aferin":7,"afiyet":50,"ağzımın su":1,"azımın su":1,"ak pak":2,"aksiyon":9,"ekşın":1,"alakalı":7," alfa":7,"anında":131,"anlamlı":6,"aralıksız":2,"durmadan":10,"arkadaş":847,"armağan":2,"ödül":47," artı":137,"arzu":12," asıl ":21,"asko":20,"aşko":11,"aşkito":1," aşık":16,"aşer":20," aşkın":39, "avantajlı":4,
             "bağımlı":18,"bahşiş":51,"başarılı":8,"başlıca":4,"bayıl":37,"bayram":46," baz ":1,"bebeğim":11,"beğeni":7,"beğend":19,"beklenti":11,"beyefendi":12,"bilerek":13,"bilgili":5,"bilinçli":4,"boğazımdan geçm":2," bol ":92,"bravo":12,"buruk":2,"canım çek":62,"canı çek":10,"cansın":1,"centilmen":1,"ciddi":55,"ivedi":2,"çabuk":31,"çare":12,"çekiliş":8,"çeşni":1,"çık aklı":24,"çık hayat":2,"çılgın":12,"çok iyi":46,
             "çözüm":41,"daima":6,"dayanışma":6,"değerli":60,"demlenmiş":1,"dengeli":9,"derle":36,"derman":3,"destek":533,"devamlı":12,"dikkatli":6,"dilek":6,"doğal":21,"doğru":150,"dolu":63,"doyam":3,"dua":24,"duyarlı":14,"dürüst":7,"düşünceli":7,"düzelt":32,"düzenli":22,"efendi":44,"eğitim":20,"eksiksiz":8,"ekstra":21,"ev yemeği":17,"eline sağlık":3,"ellerinize sağlık":4," elit":3," esas ":2,
             " esen ":1," eşit":2," etkili":8,"faydalı":3,"fazilet":1,"gayet":34,"gerçek ":349,"gerekli":41," göm":81,"gönül":20,"gönlü":11,"görev":79,"görgülü":3,"gurur":6,"güven":900,"güzel":465,"hakikaten ":2,"hakkaten":2,"hakkıyla":3,"halis":3,"hapır hupur":1,"hapur hupur":1,"hasret kal":4,"hassas":25,"hasta ol":3,"hastası":14,"havalı":3,"hayati":17,"hayır ol":1,"hayırlısı":7,"hayran":21,"hediye":160,
             "helal":158,"hemen":12,"heves":12,"hızla":7,"hızlı":85,"hijyen":32," hoş ":47,"hukuk":5,"huzur":14,"içim":64,"ikram":32,"ilave":4," ilgili":121,"iltifat":3,"incelik":4,"indirim":232,"insan sev":2,"insani":12,"inşallah":49,"inş ":14," istiyor":604," ister":195," istey":171," istemiş":39," isted":352,"işbirli":140,"iştahlı":6,"itibar":23,"iyi fikir":2,"iyi puan":2,"iyi yemek":10,"iyice":33,"iyilik":29," izin":81,"jest":15,
             "joker":170,"kabul":84,"kalp":23,"kalb":30,"kalıcı":4,"kaliteli":14,"kanka":49,"kardeşim":195,"kardeşlerim":49,"karlı":16,"kazan":332,"kefil":1,"kesintisiz":1,"keyf":60,"keyif":30,"kızarmış":34,"kibar":7,"kolay":114,"kral":157,"kurban":13,"latif":1,"layık":4,"leziz":4,"lezzetli":25,"nefis":5,"lokum":3,"makbul":1,"mantıklı":27,"medeni":5,"memnuniyet":14,"merhamet":3,"mesut":2,"meşhur":9,"minimum tutar":11,"minnet":9,
             " mis ":23,"motivasyon":3,"muhteşem":15,"mutlu":136,"mükemmel":18,"müsade":2,"müsaade":2,"müsait ":31,"nazik":12, "nitelikli":1,"nizam":4,"olağanüstü":2,"olumlu":2,"onay":80,"onur":11,"optimum":2,"otomasyon":1,"otomatik":18,"öncelik":8,"önem":250,"öner":843,"özel":209,"özendir":2,"özenli":3,"patla":44," piri ":5,"pişkin":3,"pişmiş":14," pls ":8,"pozitif":22,"prestij":1,"profesyonel":4,"promosyon":13,"rahat":122,
             "rica":62,"rüzgar":4,"safa":2,"sağlam":23,"sağlıklı":66,"sakin":32,"salim":2,"saygılı":3,"saygın":1,"sefa":7," seri":14,"sev":696,"sıcacık":6,"sipariş onay":15,"sistem":195,"sorumlu":22,"stalk":2,"sürekli":239,"sürpriz":28,"şahane":8,"şerefine":4,"şevk":1,"şımart":12,"şükran":1,"şükür":34,"taahhüt":1,"tadı güzel":2,"takdir":4,"takip":61,"taktir":2,"talep":110,"tarafsız":1,"tatlı":225,"tavla":1,"taze":13,"tecrübe":5,
             "teklif":12,"telafi":24,"temel":37,"temiz":80,"terbiyeli":3,"teşekkür":191,"teşfik":2,"teşvik":4," tez ":4,"titiz":2,"tolerans":1,"toparla":4,"toplu":160,"tutul":9,"ucuz":57,"umut":16,"usta":74,"uyanık":2,"uygun":47," uyum":41,"ücretsiz":19,"üstlen":4,"üstün":26,"vaktinde":4,"verimli":4,"vurul":1,"yakın":115,"yakışıklı":15,"yakışır":2,"yarar":22,"yardım":233,"yaşasın":11,"yemek video":24,"yeni ":196,"yerinde":49,"yeterli":18,
             "yoğunlaş":2,"yöntem":20,"yüce":6,"zahmet olmazsa":1,"zevkli":2,"abart":23,"abes":2,"abidik gubidik":2,"abuk sabuk":2,"antin kuntin":2,"absürt":1,"acayip":14,"acemi":4,"toy":13," acı ":60,"acitasyon":1,"aç kald":40," açık ":158," açım":81," açız":32,"açlıktan bayıl":5," adi ":5," ağır":35,"ağlıcam":9,"ağlicam":3,"ahlaksız":5," aksak":5," aksi ":2,"alakasız":4,"alt tarafı":9," amk":260,"amq":5,"aq":221," mk ":13,
             "skm":2,"skt":10," söv":28,"andaval":5,"anksiyete":6,"anlamsız":4,"arıza":5,"asılsız":2,"aşağı":26,"aşınmış":2,"aşırı yağ":1,"çok yağlı":7,"ayar ol":4," ayıp":65," ayı ":12," azal":38,"azar ye":17," azarla":1,"bağlanam":19,"bağlanm":23,"bahane":28,"balık hafıza":1,"balon":4," banla":3,"yasak":220,"basit":31,"başarısız":4," bat":65,"bayağı":5,"bayat":14,"baygın":2,"beceriksiz":9,"beddua":1,"beğenm":32,"beklet":56,
             "belanı versin":5,"belanızı versin":6,"bencil":6,"bitmiştir":9,"berbat":33,"bereket":30,"beter":6,"beyhude":1,"beyinsiz":1,"bez":27,"bıkkın":1,"bıktım":19,"bilgisiz":2,"bilinçsiz":107," bilme":124,"bin pişman":4,"daha asla":1,"bitkin":2,"blokl":2," bok ":26,"bomboş":1,"boş yere":11,"boşuna":27," boş ":137,"botla":3,"boykot":98,"bozuk":37,"bozulmuş":3,"böcek":15," bulan":20," buz ":78,"donmuş":4,"büyütme":1,
             "cahil":9,"camış":1,"cansız":2,"cenabet":1,"cennet":7,"cereme":13,"cesaretim yok":3,"ceza":42," cılk":1,"crash":1,"çakal":6,"çamur":6,"çekin":32,"çelişki":1,"çıkar":355,"çıkış":18,"çıldır":16," çiğ ":63,"pişmemiş":12,"çirkin":2,"çok kötü":36,"çökmüş":14,"çöktü":28," çöp ":17,"çürü":11,"dağ baş":3,"dağbaş":1,"dağın baş":4,"dağıl":4,"dağınık":2,"dalgın":4,"dandik":81," dar ":7,"dayanma sınır":16,"dedikodu":8,"değersiz":1,
             "deli ol":5,"delir":23,"dengesiz":4,"dert":19," dışı":178,"diken üst":1,"doym":44,"dökülmüş":1,"dönek":1,"dram":4,"duyar kas":4,"duygu sömür":2,"duyarsız":2,"düğüm":84,"düşman":13,"düşük":25,"düşüncesiz":3,"düzenbaz":1,"düzensiz":1,"edepsiz":1," eksik ":131," eksi ":5,"eleştiri":5,"enayi":33," engel":36,"erimiş":3," ertele":4," eşek ":3,"eyvah":4," ezik":4,"fake":1,"fani":1,"fasa fiso":1,"faydasız":1,"fazla":233,
             "felaket":12,"feleğim şaş":1,"fena":44,"fırsatç":12,"fiyasko":14,"gaflet":6,"gazabına uğra":1,"geber":7,"gecik":57,"geç gelen":59,"geçici":12,"gelm":846,"gereksiz":22,"gergin":18,"geril":12,"getirem":38,"getirm":343,"gıcık":5,"gına gel":2,"görgüsüz":6,"gözü karart":1,"gudubet":1,"hadsiz":4,"hak etmiyor":133,"hakaret":8,"haksız":8,"halt":2,"hamur":27,"haram":15,"hatalı":11,"hayal kırık":8,"haysiyetsiz":1,"hayvan":45,
             "hazetm":1,"hikaye":23," ırak ":1," uzak":99,"ıslanm":6,"ıssız":2,"iade":87,"ibne":8,"iflah olm":13,"iflas":2,"iğren":18,"ihmal":3,"ihtar":1," ilgisiz":3," illet":7,"insaf":13,"iptal":540,"israf":106," isteme":127," istemiyor":125,"istismar":11,"isyan":14,"işkence":8,"işsiz":20,"iştahsız":1," itici":3,"iyi değil":6,"kaba ":4,"kafayı ye":29,"kafayı yi":9,"kahretsin":15,"kahrolsun":1,"kalas":1,"kaldık":43,"kaldım":67,
             " kalm":275,"kan emici":3,"kanser":12,"kapısının önü":2,"kara kara düşün":432,"kara liste":5,"karışık":28,"kaybet":31,"kayış":4,"kazık":18,"kendimi tut":10,"keşke":133," kını":10,"kırıl":16,"kıtlık":1,"kifayetsiz":1,"kilo ":118,"kirlenmiş":1,"kirli":4,"kitle":19,"kokan":4,"kokm":2,"kopya":18,"korkunç":9,"köle":69,"kömür":6,"kötü ":199,"köylü":7," kuru ":20,"kusm":6,"kusur":41,"küçük":148,"küflü":4,"küstah":3," laf ":16,
             "lakayıt":1,"lanet":29,"nalet":2,"lastik":14,"leke":45," leş ":10,"lezzetsiz":5,"lüzumsuz":1,"mağdur":47,"mahsur":2,"mantıksız":4,"manyak":15,"maraz doğ":1,"mesele":14,"midem bulan":10,"mikrop":4,"minik":8,"muhatap":8,"mutsuz":28,"nefret":32,"negatif":7,"olacaksa ol":13,"odun":23," oha ":7,"olumsuz":9,"or*spu çocuğu":4,"or*spuçocuğu":0,"orospu":37,"ortadan kaldır":1,"oyala":8,"öküz":41," ölü ":16,"özensiz":4,
             "özür":72,"pahalı":59,"panik":7,"paranoyak":10,"pezevenk":6," pis ":19,"pişman":72,"problem":35,"psikopat":6,"rasgele":1,"reddet":3,"rezalet":50,"rezil":102,"risk":75,"rötar":1,"ruh hasta":7,"saçma":90," saç ":4,"sağlıksız":23,"sahte":6,"sakat":4,"sakınca":4,"salak":61,"salla":30,"saman":3,"sası":40,"savsak":1,"saygısız":9,"sebepsiz":3,"serseri":3,"sert":3,"ses seda yok":2,"sıfır":28,"sıkıl":53,"sıkıntı":77,"sıradan":7,
             "sızlan":15,"sinek":4,"sipariş hata":2,"sipariş iptal":88,"sitem":5,"sivrisinek":2,"skandal":16,"soğukta":35,"soğuk":66,"soğumuş":4,"sorm":49,"sorumsuz":2,"sorun":200,"sömür":23,"sözde":12," suç":79,"sürün":8,"şaka":58,"şans gülm":1,"şerefsiz":24,"şeytan":7,"şımarık":5,"şikayet":133,"şişir":4,"şişko patates":1,"şopar":1,"şüpheli":1,"taciz":245,"tadı yok":2,"takat":2,"talan et":1,"talihsiz":2,"tasa ":1,
             "taş ":33,"tatava yap":3,"tatsız":1,"tehlike":45,"tekel":9,"telaş":4,"tembel":8,"terbiyesiz":20,"ters":138,"tırs":14,"toz":7,"trib":10,"trip":22,"tuzsuz":1,"tüketme":36,"tükür":19,"tüy":18,"uçurum":1,"ufak":52,"uğraş":86,"ukala":7," ulan":55,"ulaşam":67,"ulaşmam":5,"ulaşm":77,"umrumda değil":4,"umrunda değil":4,"umursam":7,"unutmuş":48,"unutul":9," usan":1," utan":54,"uyar":98,"uydur":46,"ürkütücü":1," üşen":110,"üzgün":59,
             "üzül":72,"üzüyo":9,"üzücü":5,"vahim":3,"vasat":6,"vazgeç":69,"verem":358,"verimsiz":1,"vıcık":6,"vicdan azab":14,"vicdansız":9,"vizyonsuz":8,"yağı don":1,"yağsız":2,"yalaka":1,"yalan":68,"yanlış":219,"yamuk":1,"yanık":4,"yanıl":9,"yanmış":5,"yapışmış":1,"yaram":18,"yaratık":2,"yaşlan":2,"yavaş":64,"yavşak":87,"yazık":89,"yemek yok":475,"yemiyo":105,"yerlerde":136,"yeter artık":3,"yeter yahu":1,"yetersiz":9," yok ":1840,
             "yorgun":27,"zararlı":5,"zarar ":24,"zehir":17,"zevksiz":1,"zıkkım":14,"ziyan":5,"zor bela":1,"zoraki":2,"zorla":63,"zorunda bırak":6,"zorunda kal":431}
cv_sentimentlexiconwords_inalldataset
# Out:
# {'10 puan': 3,
#  'number one': 1,
#  '10/10': 24,
#  '6/10': 1,
#  '8/10': 1,
#  'acar': 4,
#  'acele': 121,
#  'acil': 80,
#  'adalet': 4,
#  'aferin': 7,
#  'afiyet': 50,
#  'ağzımın su': 1,
#  'azımın su': 1,
#  'ak pak': 2,
#  'aksiyon': 9,
#  'ekşın': 1,
#  'alakalı': 7,
#  ' alfa': 7,
#  'anında': 131,
#  'anlamlı': 6,
#  'aralıksız': 2,
#  'durmadan': 10,
#  'arkadaş': 847,
#  'armağan': 2,
#  'ödül': 47,
#  ' artı': 137,
#  'arzu': 12,
#  ' asıl ': 21,
#  'asko': 20,
#  'aşko': 11,
#  'aşkito': 1,
#  ' aşık': 16,
#  'aşer': 20,
#  ' aşkın': 39,
#  'avantajlı': 4,
#  'bağımlı': 18,
#  'bahşiş': 51,
#  'başarılı': 8,
#  'başlıca': 4,
#  'bayıl': 37,
#  'bayram': 46,
#  ' baz ': 1,
#  'bebeğim': 11,
#  'beğeni': 7,
#  'beğend': 19,
#  'beklenti': 11,
#  'beyefendi': 12,
#  'bilerek': 13,
#  'bilgili': 5,
#  'bilinçli': 4,
#  'boğazımdan geçm': 2,
#  ' bol ': 92,
#  'bravo': 12,
#  'buruk': 2,
#  'canım çek': 62,
#  'canı çek': 10,
#  'cansın': 1,
#  'centilmen': 1,
# ...

# %%
#cv_sentimentlexiconwords_inalldataset_wordcloud

# %%
import matplotlib.pyplot as plt
wc = WordCloud(width=800, height=400, max_words=400).generate_from_frequencies(cv_sentimentlexiconwords_inalldataset)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#countvector_of_product_service_lexicon_words_in_all_dataset_32000_fraction_tweets

# %%
cv_productservicelexiconwords_inalldataset={"abur cubur":24," acı ":60,"adet":64,"tane":528,"ağız tadı":5,"altın günü yiyecek":1,"ana yemek":21,"aperatif":2,"aşırı yağ":1,"çok yağlı":7, "ayran":105,"azıcık":4,
               "baharat":13," bal ":6,"bayat":14,"besin":56,"biber":41,"bisküvi":3," bol ":92,"bozuk":37,"bozulmuş":3,"böcek":15,"börek":41,"burger":1078,"buruk":2," buz ":78,"donmuş":4,
               "büyük boy":22,"canım çek":62,"canı çek":10,"cips":11,"çeşni":1,"çevirm":11,"çıtır":9," çiğ ":63,"pişmemiş":12,"çoban":2," çöp ":17,"çörek":1,"dağıl":4,"damak tadı":3,
               "damak zevk":2,"dolma":12,"domates":23,"double":7,"duble":4,"doym":44,"doyum":1,"doyurucu":7,"döner":780,"dünden kalan":2,"dürüm":137," ekle ":4,"ekşim":1," ekmek ":290,
               " eksik ":131," ekşi":6,"el yapım":2,"ev yapım":4,"ev yemeği":17," erzak":2,"eşantiyon":1," etli":66," etsiz":5,"fast food":65,"fastfood":14,"futuristik":1,"garnitür":2,
               "gevrek":3,"gıda":105,"gluten":1,"gram":102,"gurme":6,"hafif yemek":2,"hamburger":692,"hamur":27,"haram":15,"hastası":14,"hatay usul":11,"havyar":2,"hazır yemek":57,
               "helal":158," hoş ":47," ısıt":25,"ıspanak":11,"iade":87,"içecek":67," içki ":9,"içli köfte":17,"ikram":32,"kadınbudu":3,"kalın hamur":2,"karbonhidrat":5,"karışık":28,
               "kaşarlı":27,"katık":8,"kavurma":13,"kayış":4,"köpek yem":3,"kestane":4,"ketçap":56," kıl ":5,"kıtır":2,"kıyma":41,"kızarmış":34,"kızartm":23,"kilo ":118,"kişi başı":9,
               "klasik":16,"kokan":4,"kokm":2,"koku":45,"konserve":2,"köfte":271,"kömür":6,"kurt":56," kuru ":20,"kusm":6,"kuşbaşı":16,"küçük":148,"küflü":4,"lahmacun":1222,"lastik":14,
               "latif":1,"latte":4,"leziz":4,"lezzetli":25,"nefis":5,"lezzetsiz":5,"lokma":37,"lokum":3,"lüfer":1,"makarna":108,"martı eti":3,"marul":9," maya":9,"mayonez":62,"meşrubat":3,
               "meyve":20,"meze ":6,"mide":92,"minik":8," mis ":23,"nane":10,"organik":3,"orta boy":10,"öğün":41,"ölçü":4,"patates":114,"patlıcan":13,"peynir":69,"pide":497,"pilav":89,
               "pişmiş":14,"pizza":672,"poğaça":6,"porsiyon":110,"pörsüm":1,"reçel":1," saç ":4,"sağlıklı":66,"sağlıksız":23,"salata":103,"salça":12,"saman":3,"sarımsak":7,"sası":40,"sebze":42,
               "sıcacık":6,"sinek":4,"soğan":66,"soğuk":66,"soğumuş":4,"son kullanma tarih":2," sos ":28,"sucuk":19,"sufle":20,"sulu":10,"şalgam":12,"şeker":29,"şerbet":1,"taraftar":7,
               "taş ":33,"tatlı":225,"tatsız":1,"tavuk":264,"taze":13,"tereyağ":14,"turşu":44,"tuzlu":7,"tuzsuz":1,"ufak":52,"urfa":14,"ürün":303,"vegan":44,"vejetaryan":5,"vejeteryan":11,
               "vıcık":6,"yağı don":1,"yağlı":31,"yağsız":2,"yanık":4,"yanmış":5,"yapışmış":1,"yarım":115,"yemiş":95,"yeşillik":7,"yöresel":5,"yudum":11,"yumurta":44,"zehir":17,"zevkli":2,
               "₺":51,"lira":383,"nakit":32," para ":258," tl":495,"3d secure":2,"abone":2,"acele":121,"acemi":4,"toy":13," açık ":158," açıl":81,"adalet":4," adam":569,"adisyon":3," adi ":5,
               "adres":606,"ikamet":5,"ahlaksız":5,"ak pak":2," aksi ":2,"aktarm":1,"alakalı":7,"alakasız":4," alan ":52,"bölge":82,"civar":14," etraf":10,"konum":52,"mahal":116,"mevki":29,
               "muhit":3,"semt":34,"sokak":440,"alçal":7," algı":11,"alış veriş":7,"alışveriş":186,"alt limit":8,"alt sınır":2,"altyap":9,"anasayfa":1,"ana sayfa":3,"anında":131,"anlamsız":4,
               "anlaşılm":9,"anlayış":19,"aplikasyon":12," app":14,"mobil uygulama":6,"aracı":62," asıl ":21,"asistan":7,"aşağı":26," ayı ":12," azarla":1,"bağlantı":10,"bahşiş":51,"bakım":11,
               "basit":31,"başlıca":4,"bayağı":5," baz ":1,"beceriksiz":9,"bedel":74,"beklet":56,"belgeli":1,"bencil":6,"beyhude":1,"beyinsiz":1,"bıçak":12,"bildiri":45,"bilet":11,"bilgisiz":2,
               " anda ":328,"blokl":2,"boş yere":11,"boşuna":27,"bölüm":64,"buton":15,"cahil":9,"callcenter":1,"call center":3,"canlı destek":31,"canlı yardım":104,"cevap":114,"crash":1,
               "cüzdan":49,"çaba":23,"ivedi":2,"çağrı":57,"çakal":6,"çalışan":299,"çalışm":153,"çatal":15,"çelişki":1,"çevre":41,"çıkış":18,"çiçek":52,"çirkin":2,"çökmüş":14,"çöktü":28,
               "dağ baş":3,"dağbaş":1,"dağın baş":4,"dağınık":2,"dağıtıcı":2,"dağıtım ağı":2,"dakika":457,"dk":601,"saat":2159,"dalga":47,"dalgın":4,"danışma":3,"davranış":18,"davranm":5,
               "debit":1,"setcard":1,"sodexo":14,"multinet":3,"değerli":60,"değersiz":1,"deney":37,"denk":48,"dert":18,"destek":533,"devre":3,"dezenfekte":8,"dış kapı":5,"dışardan sipariş":93,
               "dışarıdan sipariş":535,"dikkate alm":2,"diyet":146,"doğru":150,"dönem":147,"duyarsız":2,"dükkan":150,"dürüst":7,"düşük":25,"düşüncesiz":3,"düşünceli":7,"düzensiz":1,"edepsiz":1,
               " ederi":237," eğitim":20,"eksiği":2,"eleman":55,"emekçi":19,"entegrasyon":2,"entegre":3," esas ":2, " esnaf ":202," eşek ":3," eşit":2,"fatura":21,"faydasız":1,"fazilet":1,
               "fazla":233,"fiat":1,"fiyat":160,"filtre":11,"firma":772," fiş":24,"gamsız":1,"gayret":10,"gece yarısı":12,"gecik":57,"geç gelen":59,"gel al":35,"gel-al":3,"gelen abi":1,"gelen arkadaş":4,
               "gelir":549,"gerçek ":349,"gereksiz":22,"getiren":157,"getirtm":4,"gönderi":166,"gönderm":222,"görev":79,"görgülü":3,"görgüsüz":6,"görmem":10,"görüş":56,"götürm":26,"haberleş":2,
               "hack":12,"hain":4,"hakaret":8,"hata ver":17,"havalı":3,"hayvan":45,"hediye":160,"hemen":12,"hes cod":4,"hes kod":7,"hesap":70,"hızlı":85,"hizmet":410,"hukuk":5," ırak ":1," uzak":99,
               "ısmarlam":9," icra":148,"ihmal":3,"ihtar":1," ileti":179,"iletm":1," ilgili":121,"ilgisiz":3," ilişki":17," ilkel":3,"indirim":232,"influencer":3,"insan sağlığı":1,"internet site":6,
               "internetten yemek siparişi":7," işçi":16,"işlem":18,"işletme":138,"işyeri":24," izin":81,"joker":170,"kaba ":4,"kaide":1,"kalas":1,"kampanya":401,"kapalı":149,"kapanmış":21,"kapanış":9,
               "kapatmış":4,"kapatmak":4,"kapıda öde":15,"kara liste":5,"karaliste":1,"kargocu":24,"karşılı":149,"kasiyer":12,"kaşık":8,"katır":1,"kaytar":1,"kazan":332,"kazık":18,"kdv":22,"kebapçı":47,
               "kısır":3,"kıymetli":42,"kifayetsiz":1,"kokorecci":1,"kokoreççi":2,"komisyon":203,"konsept":6,"kota":5,"kart":309,"kullanıcı dost":2,"kupon":54,"kural":35,"kuriye":4,"kurye":1148,
               "kurumsal":10,"küçümseme":5,"küstah":3,"lakayıt":1,"legal":2,"mail":57,"posta":14,"maliye":14,"malzeme":54,"mekan":172,"memur":13,"mendil":6,"menü":276,"merkez":270,"mesafe":61,
               "mesaj":156,"mesele":14,"meslek":8,"mevsim":6,"mezun":113,"miktar":29,"min tutar":6,"min paket tutar":1,"min sipariş tutar":3,"minimum sipariş tutar":14,"minimum tutar":11,"misli":2,
               "motokurye":2,"motosiklet":8,"motor":97,"muamele":6,"muhatap":8,"mukabil":5,"mutfak":51,"mücadele":106,"müdavim":2,"müddet":5,"müşteri":368,"naçiz":3,"nazik":12,"negatif":7,"nerde kal":15,
               "nerden gel":3,"nizam":4,"nöbet":380,"numara":221,"odun":23,"online":879,"operatör":7,"ortak":35,"otomasyon":1,"otomatik":18,"ödeme":248,"ödev":9,"öküz":41,"öner":843,"örgüt":1,
               "özen göster":5,"özenli":3,"özensiz":4,"pahalı":59,"paket servis":323,"paket sipariş":22,"paket":768," pay ":5,"peçete":9,"perhiz":2,"personel":37,"pipet":22,"platform":291,"portör":1,
               "pos cihazı":15,"poşet":67,"pratik":4,"promosyon":13,"prosedür":2,"puan":226,"range":1,"rasgele":1,"rastgele":7,"rejim":4,"reklam":229,"restoran":1436,"rozet":10,"rötar":1,"ruhsat":2,
               "rut dışı":1,"sağanak":2,"salah":1,"sapa":21,"satış":97,"savsak":1,"saygılı":3,"saygın":1,"saygısız":9,"sepetçi":3,"yemekçi":6," seri":14,"server":4,"servis":575,"sezon":16,"sıradan":7,
               "sırılsıklam":4,"sipariş hata":2,"sipariş hattı":5,"sipariş iptal":88,"sipariş not":144,"sipariş onay":15,"sipariş önce":4,"sipariş sonra":19,"sistem":195,"sitem":5,"sms":17,
               "soğuk hava":9,"soğukta":35,"sorumlu":22,"sorumsuz":2,"sorun":200,"stil":5,"story":15,"sunucu":3," süre":65,"şimdi":570,"şirket":102,"şube":194,"taciz":245,"tahsil":8,"tahsis":1,
               "taksit":3,"tarih":122,"tarz":39,"taşı":71,"tatbik":1,"tayfa":5,"tecrübe":5,"tehlike":45,"tek kişi":17,"teklif":12,"teknoloji":27,"telefon":816,"temas":162,"temel":37,"temiz":80,
               "temsilci":37,"terbiyesiz":20,"ters":138,"teslim":341," tez ":4,"ticket":2,"titiz":2,"token":3,"tolerans":1,"toplam":34,"trafik":22,"trib":10,"trip":22,"tutar":96,"tutum":3,"tüketici":7,
               "tükür":19,"türe":34,"tüy":18,"uğraş":86,"ukala":7,"ulaşam":67,"ulaşmam":5,"ulaşm":77,"ulaşım":3,"umursam":7,"unutmuş":48,"usta":74," usul":30,"uyar":98,"uygula":528," uyum":41,
               "ücret ":27,"üyeli":14,"üzücü":5,"vakit":10," vale":42,"vasıta":1,"verimli":4,"verimsiz":1,"viral":8,"virüs":221,"web site":11,"webchat":1,"yağmur":111,"yakışıklı":15,"yalın":3,
               "yanlış":219,"yanıt":6,"yaptırım":10,"yarar":22,"yasal":12,"yatkın":1,"yavşak":87,"yazılım":20,"yerel":11,"yetersiz":9,"yetkili":27,"yoğunluk":85,"yollam":253," yol ":21," yorum":238,
               "yoz":39,"yönetici":9,"yöntem":20,"yürütm":1,"zaman":827," zam ":145,"zararlı":5,"zihniyet":5}
cv_productservicelexiconwords_inalldataset
# Out:
# {'abur cubur': 24,
#  ' acı ': 60,
#  'adet': 64,
#  'tane': 528,
#  'ağız tadı': 5,
#  'altın günü yiyecek': 1,
#  'ana yemek': 21,
#  'aperatif': 2,
#  'aşırı yağ': 1,
#  'çok yağlı': 7,
#  'ayran': 105,
#  'azıcık': 4,
#  'baharat': 13,
#  ' bal ': 6,
#  'bayat': 14,
#  'besin': 56,
#  'biber': 41,
#  'bisküvi': 3,
#  ' bol ': 92,
#  'bozuk': 37,
#  'bozulmuş': 3,
#  'böcek': 15,
#  'börek': 41,
#  'burger': 1078,
#  'buruk': 2,
#  ' buz ': 78,
#  'donmuş': 4,
#  'büyük boy': 22,
#  'canım çek': 62,
#  'canı çek': 10,
#  'cips': 11,
#  'çeşni': 1,
#  'çevirm': 11,
#  'çıtır': 9,
#  ' çiğ ': 63,
#  'pişmemiş': 12,
#  'çoban': 2,
#  ' çöp ': 17,
#  'çörek': 1,
#  'dağıl': 4,
#  'damak tadı': 3,
#  'damak zevk': 2,
#  'dolma': 12,
#  'domates': 23,
#  'double': 7,
#  'duble': 4,
#  'doym': 44,
#  'doyum': 1,
#  'doyurucu': 7,
#  'döner': 780,
#  'dünden kalan': 2,
#  'dürüm': 137,
#  ' ekle ': 4,
#  'ekşim': 1,
#  ' ekmek ': 290,
#  ' eksik ': 131,
#  ' ekşi': 6,
#  'el yapım': 2,
# ...

# %%
#cv_productservicelexiconwords_inalldataset_wordcloud

# %%
import matplotlib.pyplot as plt
wc = WordCloud(width=800, height=400, max_words=400).generate_from_frequencies(cv_productservicelexiconwords_inalldataset)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
cv_all_lexiconwords_inalldataset_first_seventy_fivewords={"sipariş":1420,"yemek":13473,"yorum":4711,"saat":2159,
                                        "yok":1840,"restoran":1436,"lahmacun":1222,"kurye":1148,
                                        "burger":1078,"tane":966,"isti":912,"güven":895,
                                        "arkadaş":847,"gelm":846,"iste":821,"telefon":816,
                                        "zaman":812,"hasta":805,"döner":780,"öner":776,"firma":772,
                                        "hamburger":692,"adres":606,"dk":600,"servis":575,"şimdi":570,
                                        "adam":569,"online":548,"iptal":540,"dışarıdan sipariş":535,
                                        "destek":533,"pizza":528,"uygula":528,"pide":497,"tl":495,
                                       "yemek yok":475,"güzel":465,"dakika":457,"sev":450,"sokak":440,
                                        "kara kara düşün":432,"zorunda kal":431,"paket":412,"kampanya":401,
                                        "hizmet":396,"lira":383,"nöbet":380,"istem":372,"müşteri":368,
                                        "verem":358,"iyi":357,"çıkar":355,"getirm":343,"anda":328,
                                        "paket servis":323,"ürün":303,"çalışan":299,"süre":294,
                                        "gerçekten":291,"platform":291,"açık":277,"menü":276,"kalm":275,
                                        "hazır":271,"köfte":271,"merkez":270,"ekmek":256,"yollam":253,
                                        "ederi":246,"online sipariş":244,"taciz":242,"sürekli":239,
                                        "para":234,"yardım":233,"indirim":232}
cv_all_lexiconwords_inalldataset_first_seventy_fivewords1=cv_all_lexiconwords_inalldataset_first_seventy_fivewords.copy()
cv_all_lexiconwords_inalldataset_first_seventy_fivewords1
# Out:
# {'sipariş': 1420,
#  'yemek': 13473,
#  'yorum': 4711,
#  'saat': 2159,
#  'yok': 1840,
#  'restoran': 1436,
#  'lahmacun': 1222,
#  'kurye': 1148,
#  'burger': 1078,
#  'tane': 966,
#  'isti': 912,
#  'güven': 895,
#  'arkadaş': 847,
#  'gelm': 846,
#  'iste': 821,
#  'telefon': 816,
#  'zaman': 812,
#  'hasta': 805,
#  'döner': 780,
#  'öner': 776,
#  'firma': 772,
#  'hamburger': 692,
#  'adres': 606,
#  'dk': 600,
#  'servis': 575,
#  'şimdi': 570,
#  'adam': 569,
#  'online': 548,
#  'iptal': 540,
#  'dışarıdan sipariş': 535,
#  'destek': 533,
#  'pizza': 528,
#  'uygula': 528,
#  'pide': 497,
#  'tl': 495,
#  'yemek yok': 475,
#  'güzel': 465,
#  'dakika': 457,
#  'sev': 450,
#  'sokak': 440,
#  'kara kara düşün': 432,
#  'zorunda kal': 431,
#  'paket': 412,
#  'kampanya': 401,
#  'hizmet': 396,
#  'lira': 383,
#  'nöbet': 380,
#  'istem': 372,
#  'müşteri': 368,
#  'verem': 358,
#  'iyi': 357,
#  'çıkar': 355,
#  'getirm': 343,
#  'anda': 328,
#  'paket servis': 323,
# ...

# %%
import matplotlib.pyplot as plt
wc = WordCloud(width=800, height=400, max_words=400).generate_from_frequencies(cv_all_lexiconwords_inalldataset_first_seventy_fivewords1)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
cv_all_lexiconwords_inalldataset_first_seventy_fivewords1_keywordofdataset_excluded={"yorum":4711,"saat":2159,
                                        "yok":1840,"restoran":1436,"kurye":1148,
                                        "tane":966,"isti":912,"güven":895,
                                        "arkadaş":847,"gelm":846,"iste":821,"telefon":816,
                                        "zaman":812,"hasta":805,"öner":776,"firma":772,
                                        "adres":606,"dk":600,"servis":575,"şimdi":570,
                                        "adam":569,"online":548,"iptal":540,
                                        "destek":533,"pizza":528,"uygula":528,"tl":495,
                                      "güzel":465,"dakika":457,"sev":450,"sokak":440,
                                        "kara kara düşün":432,"zorunda kal":431,"paket":412,"kampanya":401,
                                        "hizmet":396,"lira":383,"nöbet":380,"istem":372,"müşteri":368,
                                        "verem":358,"iyi":357,"çıkar":355,"getirm":343,"anda":328,
                                        "paket servis":323,"ürün":303,"çalışan":299,"süre":294,
                                        "gerçekten":291,"platform":291,"açık":277,"menü":276,"kalm":275,
                                        "hazır":271,"köfte":271,"merkez":270,"ekmek":256,"yollam":253,
                                        "ederi":246,"taciz":242,"sürekli":239,
                                        "para":234,"yardım":233,"indirim":232}
cv_all_lexiconwords_inalldataset_first_seventy_fivewords1_keywordofdataset_excluded1=cv_all_lexiconwords_inalldataset_first_seventy_fivewords1_keywordofdataset_excluded.copy()
cv_all_lexiconwords_inalldataset_first_seventy_fivewords1_keywordofdataset_excluded1
# Out:
# {'yorum': 4711,
#  'saat': 2159,
#  'yok': 1840,
#  'restoran': 1436,
#  'kurye': 1148,
#  'tane': 966,
#  'isti': 912,
#  'güven': 895,
#  'arkadaş': 847,
#  'gelm': 846,
#  'iste': 821,
#  'telefon': 816,
#  'zaman': 812,
#  'hasta': 805,
#  'öner': 776,
#  'firma': 772,
#  'adres': 606,
#  'dk': 600,
#  'servis': 575,
#  'şimdi': 570,
#  'adam': 569,
#  'online': 548,
#  'iptal': 540,
#  'destek': 533,
#  'pizza': 528,
#  'uygula': 528,
#  'tl': 495,
#  'güzel': 465,
#  'dakika': 457,
#  'sev': 450,
#  'sokak': 440,
#  'kara kara düşün': 432,
#  'zorunda kal': 431,
#  'paket': 412,
#  'kampanya': 401,
#  'hizmet': 396,
#  'lira': 383,
#  'nöbet': 380,
#  'istem': 372,
#  'müşteri': 368,
#  'verem': 358,
#  'iyi': 357,
#  'çıkar': 355,
#  'getirm': 343,
#  'anda': 328,
#  'paket servis': 323,
#  'ürün': 303,
#  'çalışan': 299,
#  'süre': 294,
#  'gerçekten': 291,
#  'platform': 291,
#  'açık': 277,
#  'menü': 276,
#  'kalm': 275,
#  'hazır': 271,
#  'köfte': 271,
#  'merkez': 270,
# ...

# %%
import matplotlib.pyplot as plt
wc = WordCloud(width=800, height=400, max_words=400).generate_from_frequencies(cv_all_lexiconwords_inalldataset_first_seventy_fivewords1_keywordofdataset_excluded1)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
########count_vector_of_words_of_in_its_class_dataset########

# %%
read_file=pd.read_excel(r"cv_productservicelexiconwords_inproductservicedataset.xlsx")
cv_productservicelexiconwords_inproductservicedataset=read_file.to_csv(r"cv_productservicelexiconwords_inproductservicedataset.csv", index=None)
cv_productservicelexiconwords_inproductservicedataset=pd.read_csv("cv_productservicelexiconwords_inproductservicedataset.csv")
cv_productservicelexiconwords_inproductservicedataset=pd.DataFrame(cv_productservicelexiconwords_inproductservicedataset)
cv_productservicelexiconwords_inproductservicedataset1=cv_productservicelexiconwords_inproductservicedataset.copy()
cv_productservicelexiconwords_inproductservicedataset1_graph=cv_productservicelexiconwords_inproductservicedataset1[cv_productservicelexiconwords_inproductservicedataset1["Frekans"]>500]
cv_productservicelexiconwords_inproductservicedataset1_graph.plot.bar(x="Terim", y="Frekans");

# %%
read_file=pd.read_excel(r"cv_sentimentlexiconwords_insentimentdataset.xlsx")
cv_sentimentlexiconwords_insentimentdataset=read_file.to_csv(r"cv_sentimentlexiconwords_insentimentdataset.csv", index=None)
cv_sentimentlexiconwords_insentimentdataset=pd.read_csv("cv_sentimentlexiconwords_insentimentdataset.csv")
cv_sentimentlexiconwords_insentimentdataset=pd.DataFrame(cv_sentimentlexiconwords_insentimentdataset)
cv_sentimentlexiconwords_insentimentdataset1=cv_sentimentlexiconwords_insentimentdataset.copy()
cv_sentimentlexiconwords_insentimentdataset1_graph=cv_sentimentlexiconwords_insentimentdataset1[cv_sentimentlexiconwords_insentimentdataset1["Frekans"]>500]
cv_sentimentlexiconwords_insentimentdataset1_graph.plot.bar(x="Terim", y="Frekans");

# %%
#cv_sentiment_productservice_lexiconwords_inalldataset_fordescriptive_analysis_article####

# %%
read_file=pd.read_excel(r"cv_sentiment_productservice_lexiconwords_inalldataset.xlsx")
cv_sentiment_productservice_lexiconwords_inalldataset=read_file.to_csv(r"cv_sentiment_productservice_lexiconwords_inalldataset.csv", index=None)
cv_sentiment_productservice_lexiconwords_inalldataset=pd.read_csv("cv_sentiment_productservice_lexiconwords_inalldataset.csv")
cv_sentiment_productservice_lexiconwords_inalldataset=pd.DataFrame(cv_sentiment_productservice_lexiconwords_inalldataset)
cv_sentiment_productservice_lexiconwords_inalldataset1=cv_sentiment_productservice_lexiconwords_inalldataset.copy()
cv_sentiment_productservice_lexiconwords_inalldataset1_graph=cv_sentiment_productservice_lexiconwords_inalldataset1[cv_sentiment_productservice_lexiconwords_inalldataset1["Frekans"]>500]
cv_sentiment_productservice_lexiconwords_inalldataset1_graph.plot.bar(x="Terim", y="Frekans");
